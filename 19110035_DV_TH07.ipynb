# %% [markdown]
# <a href="https://colab.research.google.com/github/ImperB-riven/Data-Visualization/blob/main/19110035_DV_TH07.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bài tập

# %%
data
# Out:
#           country              region  year  ...  population  fertility    life
# 0     Afghanistan          South Asia  1964  ...  10474903.0      7.671  33.639
# 1     Afghanistan          South Asia  1965  ...  10697983.0      7.671  34.152
# 2     Afghanistan          South Asia  1966  ...  10927724.0      7.671  34.662
# 3     Afghanistan          South Asia  1967  ...  11163656.0      7.671  35.170
# 4     Afghanistan          South Asia  1968  ...  11411022.0      7.671  35.674
# ...           ...                 ...   ...  ...         ...        ...     ...
# 8817     Zimbabwe  Sub-Saharan Africa  2009  ...  12473992.0      3.792  51.234
# 8818     Zimbabwe  Sub-Saharan Africa  2010  ...  12571454.0      3.721  53.684
# 8819     Zimbabwe  Sub-Saharan Africa  2011  ...  12754378.0      3.643  56.040
# 8820     Zimbabwe  Sub-Saharan Africa  2012  ...  13013678.0      3.564  58.142
# 8821     Zimbabwe  Sub-Saharan Africa  2013  ...  13327925.0      3.486  59.871
#
# [8202 rows x 8 columns]

# %% [markdown]
# 1.
#
#  a) Dùng dataset co2.csv, và grapminder.csv. Thực hiện lại các bước tiền xử lý dự liệu.
#
#  b) Vẽ biểu đồ biểu thị mỗi quan hệ giữa co2 và life sử dụng scatter. Với contry ở hover tool, và slider: year.
#
# c) Tính correlation giữa co2 vs life
#
# d) Tương tự b,c) nhưng mà cho co2 vs fertility.
#
# e) Tạo 1 barplot visualize co2 mỗi region, mỗi year (slider : year), hover tool : country

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
import chart_studio.plotly as py
import plotly.graph_objs as go

# %%
co2 = pd.read_csv('co2.csv')
co2.head()
# Out:
#        country  1800  1801  1802  1803  ...   2010   2011  2012   2013   2014
# 0  Afghanistan   NaN   NaN   NaN   NaN  ...  0.294  0.412  0.35  0.316  0.299
# 1      Albania   NaN   NaN   NaN   NaN  ...  1.560  1.790  1.68  1.730  1.960
# 2      Algeria   NaN   NaN   NaN   NaN  ...  3.300  3.290  3.46  3.510  3.720
# 3      Andorra   NaN   NaN   NaN   NaN  ...  6.120  5.870  5.92  5.900  5.830
# 4       Angola   NaN   NaN   NaN   NaN  ...  1.240  1.250  1.33  1.250  1.290
#
# [5 rows x 216 columns]

# %%
gapminder = pd.read_csv('gapminder.csv')
gapminder.head()
# Out:
#        Country  Year  fertility  ...  child_mortality     gdp      region
# 0  Afghanistan  1964      7.671  ...            339.7  1182.0  South Asia
# 1  Afghanistan  1965      7.671  ...            334.1  1182.0  South Asia
# 2  Afghanistan  1966      7.671  ...            328.7  1168.0  South Asia
# 3  Afghanistan  1967      7.671  ...            323.3  1173.0  South Asia
# 4  Afghanistan  1968      7.671  ...            318.1  1187.0  South Asia
#
# [5 rows x 8 columns]

# %% [markdown]
# ## a)

# %%
# Tiền xử lý dữ liêu (có trong các bài thực hành trước)
df_gm = gm[['Country', 'region']].drop_duplicates()
df_w_regions = pd.merge(co2, df_gm, left_on='country', right_on='Country', how='inner')
df_w_regions = df_w_regions.drop('Country', axis='columns')
new_co2 = pd.melt(df_w_regions, id_vars=['country', 'region'])

columns = ['country', 'region', 'year', 'co2']
new_co2.columns = columns

df_co2 = new_co2[new_co2['year'].astype('int64') > 1963]
df_co2 = df_co2.sort_values(by=['country', 'year'])
df_co2['year'] = df_co2['year'].astype('int64')
df_g = gm[['Country', 'Year', 'gdp', 'population', 'fertility', 'life']]
df_g.columns = ['country', 'year', 'gdp', 'population', 'fertility', 'life']
data = pd.merge(df_co2, df_g, on=['country', 'year'], how='left')

data = data.dropna() # Drop missing value

# %%
data
# Out:
#           country              region  year  ...  population  fertility    life
# 0     Afghanistan          South Asia  1964  ...  10474903.0      7.671  33.639
# 1     Afghanistan          South Asia  1965  ...  10697983.0      7.671  34.152
# 2     Afghanistan          South Asia  1966  ...  10927724.0      7.671  34.662
# 3     Afghanistan          South Asia  1967  ...  11163656.0      7.671  35.170
# 4     Afghanistan          South Asia  1968  ...  11411022.0      7.671  35.674
# ...           ...                 ...   ...  ...         ...        ...     ...
# 8817     Zimbabwe  Sub-Saharan Africa  2009  ...  12473992.0      3.792  51.234
# 8818     Zimbabwe  Sub-Saharan Africa  2010  ...  12571454.0      3.721  53.684
# 8819     Zimbabwe  Sub-Saharan Africa  2011  ...  12754378.0      3.643  56.040
# 8820     Zimbabwe  Sub-Saharan Africa  2012  ...  13013678.0      3.564  58.142
# 8821     Zimbabwe  Sub-Saharan Africa  2013  ...  13327925.0      3.486  59.871
#
# [8202 rows x 8 columns]

# %% [markdown]
# ## b)

# %%
fig = px.scatter(data, x = "co2", y = "life", color = "region",
                 hover_data = ['country'], animation_frame = "year")

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="573decd3-d262-4817-97ba-71cf309465c4" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("573decd3-d262-4817-97ba-71cf309465c4")) {
#                     Plotly.newPlot(
#                         '573decd3-d262-4817-97ba-71cf309465c4',
#                         [{"customdata": [["Afghanistan"], ["Bangladesh"], ["India"], ["Nepal"], ["Pakistan"], ["Sri Lanka"]], "hoverlabel": {"namelength": 0}, "hovertemplate": "region=South Asia<br>year=1964<br>co2=%{x}<br>life=%{y}<br>country=%{customdata[0]}", "legendgroup": "region=South Asia", "marker": {"color": "#636efa", "symbol": "circle"}, "mode": "markers", "name": "region=South Asia", "showlegend": true, "type": "scatter", "x": [0.0863, 0.055, 0.309, 0.013999999999999999, 0.324, 0.21], "xaxis": "x", "y": [33.639, 49.297, 44.375, 40.071, 49.807, 61.09], "yaxis": "y"}, {"customdata": [["Albania"], ["Armenia"], ["Austria"], ["Azerbaijan"], ["Belarus"], ["Belgium"], ["Bulgaria"], ["Cyprus"], ["Denmark"], ["Finland"], ["France"], ["Georgia"], ["Germany"], ["Greece"], ["Hungary"], ["Iceland"], ["Ireland"], ["Italy"], ["Kazakhstan"], ["Lithuania"], ["Luxembourg"], ["Malta"], ["Moldova"], ["Netherlands"], ["Norway"], ["Poland"], ["Portugal"], ["Romania"], ["Russia"], ["Slovak Republic"], ["Spain"], ["Sweden"], ["Switzerland"], ["Tajikistan"], ["Turkey"], ["Turkmenistan"], ["Ukraine"], ["United Kingdom"], ["Uzbekistan"]], "hoverlabel": {"namelength": 0}, "hovertemplate": "region=Europe & Central Asia<br>year=1964<br>co2=%{x}<br>life=%{y}<br>country=%{customdata[0]}", "legendgroup": "region=Europe & Central Asia", "marker": {"color": "#EF553B", "symbol": "circle"}, "mode": "markers", "name": "region=Europe & Central Asia", "showlegend": true, "type": "scatter", "x": [1.09, 1.45, 5.37, 6.75, 5.51, 11.0, 5.25, 1.73, 9.14, 5.02, 7.13, 1.91, 12.8, 1.57, 6.16, 6.91, 5.0, 3.43, 12.1, 4.05, 37.6, 1.56, 3.43, 8.01, 4.38, 7.83, 1.23, 3.75, 8.87, 9.24, 2.02, 7.86, 4.92, 1.63, 0.871, 9.64, 7.53, 11.3, 6.11], "xaxis": "x", "y": [65.475, 67.714, 70.16, 62.701, 73.48, 70.73, 71.14, 70.895, 72.52, 69.37, 71.32, 65.293, 70.6511001188, 69.493, 69.48, 73.57, 70.49, 70.4, 60.19600000000001, 71.94, 69.07, 68.839, 63.496, 73.73, 73.61, 68.8, 65.24, 67.73, 69.85, 71.09, 70.58, 73.73, 72.2, 57.84, 48.313, 56.181, 72.19, 71.62, 60.682], "yaxis": "y"}, {"customdata": [["Algeria"], ["Bahrain"], ["Djibouti"], ["Egypt"], ["Iran"], ["Iraq"], ["Israel"], ["Jordan"], ["Kuwait"], ["Lebanon"], ["Libya"], ["Morocco"], ["Oman"], ["Qatar"], ["Saudi Arabia"], ["Syria"], ["Tunisia"], ["United Arab Emirates"]], "hoverlabel": {"namelength": 0}, "hovertemplate": "region=Middle East & North Africa<br>year=1964<br>co2=%{x}<br>life=%{y}<br>country=%{customdata[0]}", "legendgroup": "region=Middle East & North Africa", "marker": {"color": "#00cc96", "symbol": "circle"}, "mode": "markers", "name": "region=Middle East & North Africa", "showlegend": true, "type": "scatter", "x": [0.46, 8.74, 0.784, 0.8490000000000001, 1.96, 1.12, 3.74, 1.13, 59.6, 1.6, 0.39799999999999996, 0.319, 0.0181, 92.9, 1.51, 0.84, 0.618, 0.132], "xaxis": "x", "y": [47.953, 57.182, 45.727, 50.133, 47.173, 52.73, 69.855, 55.765, 62.78100000000001, 64.435, 48.914, 50.167, 45.895, 64.139, 47.78100000000001, 55.028, 44.903, 56.328], "yaxis": "y"}, {"customdata": [["Angola"], ["Benin"], ["Burkina Faso"], ["Burundi"], ["Cameroon"], ["Cape Verde"], ["Chad"], ["Comoros"], ["Congo, Dem. Rep."], ["Congo, Rep."], ["Cote d'Ivoire"], ["Equatorial Guinea"], ["Ethiopia"], ["Gabon"], ["Gambia"], ["Ghana"], ["Guinea"], ["Guinea-Bissau"], ["Kenya"], ["Liberia"], ["Madagascar"], ["Malawi"], ["Mali"], ["Mauritania"], ["Mauritius"], ["Mozambique"], ["Niger"], ["Nigeria"], ["Rwanda"], ["Sao Tome and Principe"], ["Senegal"], ["Seychelles"], ["Sierra Leone"], ["Somalia"], ["South Africa"], ["Sudan"], ["Swaziland"], ["Tanzania"], ["Togo"], ["Uganda"], ["Zambia"], ["Zimbabwe"]], "hoverlabel": {"namelength": 0}, "hovertemplate": "region=Sub-Saharan Africa<br>year=1964<br>co2=%{x}<br>life=%{y}<br>country=%{customdata[0]}", "legendgroup": "region=Sub-Saharan Africa", "marker": {"color": "#ab63fa", "symbol": "circle"}, "mode": "markers", "name": "region=Sub-Saharan Africa", "showlegend": true, "type": "scatter", "x": [0.201, 0.05 ...

# %% [markdown]
# ## c)

# %%
data['co2'].corr(data['life'])
# Out:
# 0.40288934295677564

# %% [markdown]
# ## d)

# %%
fig = px.scatter(data, x = "co2", y = "fertility", color = "region",
                 hover_data = ['country'], animation_frame = "year")

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="0ebc6749-5664-434b-a499-3f629a918371" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("0ebc6749-5664-434b-a499-3f629a918371")) {
#                     Plotly.newPlot(
#                         '0ebc6749-5664-434b-a499-3f629a918371',
#                         [{"customdata": [["Afghanistan"], ["Bangladesh"], ["India"], ["Nepal"], ["Pakistan"], ["Sri Lanka"]], "hoverlabel": {"namelength": 0}, "hovertemplate": "region=South Asia<br>year=1964<br>co2=%{x}<br>fertility=%{y}<br>country=%{customdata[0]}", "legendgroup": "region=South Asia", "marker": {"color": "#636efa", "symbol": "circle"}, "mode": "markers", "name": "region=South Asia", "showlegend": true, "type": "scatter", "x": [0.0863, 0.055, 0.309, 0.013999999999999999, 0.324, 0.21], "xaxis": "x", "y": [7.671, 6.853, 5.807, 5.997000000000001, 6.6, 5.067], "yaxis": "y"}, {"customdata": [["Albania"], ["Armenia"], ["Austria"], ["Azerbaijan"], ["Belarus"], ["Belgium"], ["Bulgaria"], ["Cyprus"], ["Denmark"], ["Finland"], ["France"], ["Georgia"], ["Germany"], ["Greece"], ["Hungary"], ["Iceland"], ["Ireland"], ["Italy"], ["Kazakhstan"], ["Lithuania"], ["Luxembourg"], ["Malta"], ["Moldova"], ["Netherlands"], ["Norway"], ["Poland"], ["Portugal"], ["Romania"], ["Russia"], ["Slovak Republic"], ["Spain"], ["Sweden"], ["Switzerland"], ["Tajikistan"], ["Turkey"], ["Turkmenistan"], ["Ukraine"], ["United Kingdom"], ["Uzbekistan"]], "hoverlabel": {"namelength": 0}, "hovertemplate": "region=Europe & Central Asia<br>year=1964<br>co2=%{x}<br>fertility=%{y}<br>country=%{customdata[0]}", "legendgroup": "region=Europe & Central Asia", "marker": {"color": "#EF553B", "symbol": "circle"}, "mode": "markers", "name": "region=Europe & Central Asia", "showlegend": true, "type": "scatter", "x": [1.09, 1.45, 5.37, 6.75, 5.51, 11.0, 5.25, 1.73, 9.14, 5.02, 7.13, 1.91, 12.8, 1.57, 6.16, 6.91, 5.0, 3.43, 12.1, 4.05, 37.6, 1.56, 3.43, 8.01, 4.38, 7.83, 1.23, 3.75, 8.87, 9.24, 2.02, 7.86, 4.92, 1.63, 0.871, 9.64, 7.53, 11.3, 6.11], "xaxis": "x", "y": [5.711, 4.1610000000000005, 2.795, 5.468, 2.6010000000000004, 2.599, 2.181, 3.249, 2.602, 2.58, 2.8, 2.864, 2.494, 2.259, 1.876, 3.736, 3.987, 2.5, 4.2010000000000005, 2.378, 2.374, 2.798, 2.989, 3.17, 2.96, 2.5, 3.189, 1.9469026549, 2.16, 2.779, 2.826, 2.475, 2.564, 6.433, 6.029, 6.6629999999999985, 2.07, 2.7910000000000004, 6.777], "yaxis": "y"}, {"customdata": [["Algeria"], ["Bahrain"], ["Djibouti"], ["Egypt"], ["Iran"], ["Iraq"], ["Israel"], ["Jordan"], ["Kuwait"], ["Lebanon"], ["Libya"], ["Morocco"], ["Oman"], ["Qatar"], ["Saudi Arabia"], ["Syria"], ["Tunisia"], ["United Arab Emirates"]], "hoverlabel": {"namelength": 0}, "hovertemplate": "region=Middle East & North Africa<br>year=1964<br>co2=%{x}<br>fertility=%{y}<br>country=%{customdata[0]}", "legendgroup": "region=Middle East & North Africa", "marker": {"color": "#00cc96", "symbol": "circle"}, "mode": "markers", "name": "region=Middle East & North Africa", "showlegend": true, "type": "scatter", "x": [0.46, 8.74, 0.784, 0.8490000000000001, 1.96, 1.12, 3.74, 1.13, 59.6, 1.6, 0.39799999999999996, 0.319, 0.0181, 92.9, 1.51, 0.84, 0.618, 0.132], "xaxis": "x", "y": [7.653, 7.192, 6.595, 6.471, 6.8679999999999986, 6.872000000000001, 3.817, 8.033999999999999, 7.381, 5.582999999999998, 7.676, 7.119, 7.263, 6.985, 7.2570000000000014, 7.555, 7.107, 6.8610000000000015], "yaxis": "y"}, {"customdata": [["Angola"], ["Benin"], ["Burkina Faso"], ["Burundi"], ["Cameroon"], ["Cape Verde"], ["Chad"], ["Comoros"], ["Congo, Dem. Rep."], ["Congo, Rep."], ["Cote d'Ivoire"], ["Equatorial Guinea"], ["Ethiopia"], ["Gabon"], ["Gambia"], ["Ghana"], ["Guinea"], ["Guinea-Bissau"], ["Kenya"], ["Liberia"], ["Madagascar"], ["Malawi"], ["Mali"], ["Mauritania"], ["Mauritius"], ["Mozambique"], ["Niger"], ["Nigeria"], ["Rwanda"], ["Sao Tome and Principe"], ["Senegal"], ["Seychelles"], ["Sierra Leone"], ["Somalia"], ["South Africa"], ["Sudan"], ["Swaziland"], ["Tanzania"], ["Togo"], ["Uganda"], ["Zambia"], ["Zimbabwe"]], "hoverlabel": {"namelength": 0}, "hovertemplate": "region=Sub-Saharan Africa<br>year=1964<br>co2=%{x}<br>fertility=%{y}<br>country=%{customdata[0]}", "legendgroup": "region=Sub-Saharan Africa", "marker": {"color": "#ab63fa", "symbol": "circle"}, "mode": "markers", ...

# %%
data['co2'].corr(data['fertility'])
# Out:
# -0.31439742304488627

# %% [markdown]
# ## e)

# %%
fig = px.bar(data, x = 'region', y = 'co2', barmode='group',
                   hover_name='country')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="2d8c3368-1265-4289-b9ba-470ae3ab85fc" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("2d8c3368-1265-4289-b9ba-470ae3ab85fc")) {
#                     Plotly.newPlot(
#                         '2d8c3368-1265-4289-b9ba-470ae3ab85fc',
#                         [{"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "<b>%{hovertext}</b><br><br>region=%{x}<br>co2=%{y}", "hovertext": ["Afghanistan", "Afghanistan", "Afghanistan", "Afghanistan", "Afghanistan", "Afghanistan", "Afghanistan", "Afghanistan", "Afghanistan", "Afghanistan", "Afghanistan", "Afghanistan", "Afghanistan", "Afghanistan", "Afghanistan", "Afghanistan", "Afghanistan", "Afghanistan", "Afghanistan", "Afghanistan", "Afghanistan", "Afghanistan", "Afghanistan", "Afghanistan", "Afghanistan", "Afghanistan", "Afghanistan", "Afghanistan", "Afghanistan", "Afghanistan", "Afghanistan", "Afghanistan", "Afghanistan", "Afghanistan", "Afghanistan", "Afghanistan", "Afghanistan", "Afghanistan", "Afghanistan", "Afghanistan", "Afghanistan", "Afghanistan", "Afghanistan", "Afghanistan", "Afghanistan", "Afghanistan", "Afghanistan", "Afghanistan", "Afghanistan", "Afghanistan", "Albania", "Albania", "Albania", "Albania", "Albania", "Albania", "Albania", "Albania", "Albania", "Albania", "Albania", "Albania", "Albania", "Albania", "Albania", "Albania", "Albania", "Albania", "Albania", "Albania", "Albania", "Albania", "Albania", "Albania", "Albania", "Albania", "Albania", "Albania", "Albania", "Albania", "Albania", "Albania", "Albania", "Albania", "Albania", "Albania", "Albania", "Albania", "Albania", "Albania", "Albania", "Albania", "Albania", "Albania", "Albania", "Albania", "Albania", "Albania", "Albania", "Albania", "Algeria", "Algeria", "Algeria", "Algeria", "Algeria", "Algeria", "Algeria", "Algeria", "Algeria", "Algeria", "Algeria", "Algeria", "Algeria", "Algeria", "Algeria", "Algeria", "Algeria", "Algeria", "Algeria", "Algeria", "Algeria", "Algeria", "Algeria", "Algeria", "Algeria", "Algeria", "Algeria", "Algeria", "Algeria", "Algeria", "Algeria", "Algeria", "Algeria", "Algeria", "Algeria", "Algeria", "Algeria", "Algeria", "Algeria", "Algeria", "Algeria", "Algeria", "Algeria", "Algeria", "Algeria", "Algeria", "Algeria", "Algeria", "Algeria", "Algeria", "Angola", "Angola", "Angola", "Angola", "Angola", "Angola", "Angola", "Angola", "Angola", "Angola", "Angola", "Angola", "Angola", "Angola", "Angola", "Angola", "Angola", "Angola", "Angola", "Angola", "Angola", "Angola", "Angola", "Angola", "Angola", "Angola", "Angola", "Angola", "Angola", "Angola", "Angola", "Angola", "Angola", "Angola", "Angola", "Angola", "Angola", "Angola", "Angola", "Angola", "Angola", "Angola", "Angola", "Angola", "Angola", "Angola", "Angola", "Angola", "Angola", "Angola", "Antigua and Barbuda", "Antigua and Barbuda", "Antigua and Barbuda", "Antigua and Barbuda", "Antigua and Barbuda", "Antigua and Barbuda", "Antigua and Barbuda", "Antigua and Barbuda", "Antigua and Barbuda", "Antigua and Barbuda", "Antigua and Barbuda", "Antigua and Barbuda", "Antigua and Barbuda", "Antigua and Barbuda", "Antigua and Barbuda", "Antigua and Barbuda", "Antigua and Barbuda", "Antigua and Barbuda", "Antigua and Barbuda", "Antigua and Barbuda", "Antigua and Barbuda", "Antigua and Barbuda", "Antigua and Barbuda", "Antigua and Barbuda", "Antigua and Barbuda", "Antigua and Barbuda", "Antigua and Barbuda", "Antigua and Barbuda", "Antigua and Barbuda", "Antigua and Barbuda", "Antigua and Barbuda", "Antigua and Barbuda", "Antigua and Barbuda", "Antigua and Barbuda", "Antigua and Barbuda", "Antigua and Barbuda", "Antigua and Barbuda", "Antigua and Barbuda", "Antigua and Barbuda", "Antigua and Barbuda", "Antigua and Barbuda", "Antigua and Barbuda", "Antigua and Barbuda", "Antigua and Barbuda", "Antigua and Barbuda", "Antigua and Barbuda", "Antigua and Barbuda", "Antigua and Barbuda", "Antigua and Barbuda", "Antigua and Barbuda", "Argentina", "Argentina", "Argentina", "Argentina", "Argentina", "Argentina", "Argentina", "Argentina", "Argentina", "Argentina", "Argentina", "Argentina", "Argentina", "Argentina", "Argentina", "Argentina", "Argentina", "Argentina", "Argentina", "Argentina", "Argentina", "Argentina", "Argentina", "Argentina", "Argentina", "Arge ...
